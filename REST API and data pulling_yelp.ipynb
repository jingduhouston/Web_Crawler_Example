# %% [markdown]
# ## A lot of websites support REST API to query data, and in your daily job you will use it very often. RESTful API = REpresentational State Transfer.
#
# Key points of REST API:
#
# 1. Client-Server
# 2. Stateless
# 3. Cacheable
# 4. Uniform-interface
# 5. Layered System
# 6. Code on demond
#
# ## REST API is a preferred way to pull data from websites using crawlers
# 1. You can get structured data directly, and easily parse them into dataframe
# 2. It's much more stable than a web crawler, website can update front page frequently but will always keep the API query the same syntax/format, or have compatibility support -- a lot of apps depend on the reliability of their API service
# 3. It's more cost effective to both you and the web server
# 4. It allows to query some data unseen from web page e.g. stock price at tick level

# %% [markdown]
# ## REST API consist of: a base URL + standard HTTP method (Get, Put, Post, Delete) + a media type (mostly JSON or XML)

# %% [markdown]
# In python, we can use
# 1. requests to send/receive HTTP request from client side
# 2. json to serialize and deserialize data
# 3. flask to build up web server to response to HTTP request
#
# Let's dive in with an example from Yelp.
#
# Go to https://www.yelp.com/developers/documentation/v3/business_search (you may need to sign up Yelp developer's account to get access to these documentations)
# Read through this page, and understand
# 1. What HTTP method should be used?
# 2. What is the basic endpoint?
# 3. What is the format of the response body?
# 4. Can you figure out how to search for restaurants within 10 miles of zip code 94583?
#
# Now go to https://www.yelp.com/developers/v3/manage_app  to add an app to your developer's account, get your client ID and app key, which will be used later. The default daily request limit is 5000.

# %%
#pip install requests if you don't already have it
import requests
#test if your request is working fine, you should be getting a status code of 200 from below command
response = requests.get('https://api.github.com')
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Some common HTTP response code:
# 200: Everything OK
# 400: Bad request, check your request syntax
# 401/403: Unathorized, you may need permission
# 404: Page not found, you know it
# 405: Bad method
# 500: Internal Server Error, check your server code
#
# A HTTP request example:
#
# POST /cgi-bin/process.cgi HTTP/1.1
# User-Agent: Mozilla/4.0 (compatible; MSIE5.01; Windows NT)
# Host: www.tutorialspoint.com
# Content-Type: application/x-www-form-urlencoded
# Content-Length: length
# Accept-Language: en-us
# Accept-Encoding: gzip, deflate
# Connection: Keep-Alive
#
# licenseID=string&content=string&/paramsXML=string

# %%
#let's try to send GET request to Yelp, replace the API_Key with yours
API_Key = '_LDe-qw1I0HiLe1TJCK2bHBYX2JoBxhqfs8ARQeU4ox_0mg2MGOHvqkD9A_dXolqK1EW1pkmv7Ios8WcmoYfi1I65-cW-0M4v_GFuEhz1_ujT8vHKTifwc0W-P_sY3Yx'
url = 'https://api.yelp.com/v3/businesses/search'
params = {
    'term':'Restaurants',
    'location':'Houston, TX 77024',
    'radius':'32000',
    'limit':'20'
}
headers = {
    'Authorization': 'Bearer %s' % API_Key,
    'Content-Type':'application/json'
}
#the browser needs full url to work, requests helps you to automatically format those urls
#e.g. https://www.yelp.com/search?find_desc=Restaurants&find_loc=San+Ramon%2C+CA&ns=1
response = requests.get(url, params=params, headers=headers, json=None) 
#GET request usually don't send data to server, so json=None. If you need to POST data, you can use json={'key':'value'}

# %%
print(response)
# Out:
# <Response [200]>

# %%
# to view the contents of the response
response.content
# Out:
# b'{"businesses": [{"id": "c7_PCKjymhTEx-418TUQrw", "alias": "kp-s-kitchen-houston", "name": "KP\\u2019s Kitchen", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-LJMRBUGLCRuYHBU-D3MhA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kp-s-kitchen-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 166, "categories": [{"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 29.7851283, "longitude": -95.4932661}, "transactions": [], "price": "$$", "location": {"address1": "8412 Katy Fwy", "address2": "Ste 350", "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["8412 Katy Fwy", "Ste 350", "Houston, TX 77024"]}, "phone": "+17136770921", "display_phone": "(713) 677-0921", "distance": 2139.3439656421756}, {"id": "0aH34yn_UAyx5g9aGzBjZw", "alias": "ember-and-greens-houston", "name": "Ember & Greens", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/bIEXqm_P8K9kkxnOIFlfMw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ember-and-greens-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 307, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "comfortfood", "title": "Comfort Food"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.5, "coordinates": {"latitude": 29.78227, "longitude": -95.52455}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "9403B Katy Fwy", "address2": null, "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["9403B Katy Fwy", "Houston, TX 77024"]}, "phone": "+17134653333", "display_phone": "(713) 465-3333", "distance": 2467.494343094968}, {"id": "nqnD2CxTvXnkMcmSjFpd6A", "alias": "postino-town-and-country-houston-5", "name": "Postino Town & Country", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/4i15A6UISO53Cd97qM2tLA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/postino-town-and-country-houston-5?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 203, "categories": [{"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "tapasmallplates", "title": "Tapas/Small Plates"}], "rating": 4.5, "coordinates": {"latitude": 29.778048771930823, "longitude": -95.56105504344312}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "791 Town And Country Blvd", "address2": "Ste 146", "address3": null, "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["791 Town And Country Blvd", "Ste 146", "Houston, TX 77024"]}, "phone": "+17135748337", "display_phone": "(713) 574-8337", "distance": 5537.864194382998}, {"id": "hSFXjuYnlCaW25yJ005_lg", "alias": "by-popular-demand-houston", "name": "By Popular Demand", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/aq13FkuLz7EUXBLky_7tVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/by-popular-demand-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 59, "categories": [{"alias": "whiskeybars", "title": "Whiskey Bars"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.5, "coordinates": {"latitude": 29.7664124, "longitude": -95.5486411}, "transactions": ["delivery"], "location": {"address1": "12420 Memorial Dr", "address2": null, "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["12420 Memorial Dr", "Houston, TX 77024"]}, "phone": "+12815004601", "display_phone": "(281) 500-4601", "distance": 4358.258509758105}, {"id": "RTau-YpBii_bnHbSEG9zSQ", "alias":  ...

# %%
#other properties and methods of response object, a full list of available properties and methods can be found here
#https://www.w3schools.com/python/ref_requests_response.asp
print('cookies is ' + str(response.cookies) + '\n')
print('headers is ' + str(response.headers) + '\n')
print('response body is ' + str(response.text))
# Out:
# cookies is <RequestsCookieJar[]>
#
# headers is {'Connection': 'keep-alive', 'content-type': 'application/json', 'x-routing-service': 'routing-main--useast1-7656bbbcf9-d4w26; site=public_api_v3', 'x-b3-sampled': '0', 'ratelimit-dailylimit': '5000.0', 'server': 'envoy', 'ratelimit-remaining': '4998.0', 'x-zipkin-id': 'ebe94db3ec0621ab', 'ratelimit-resettime': '2023-02-17T00:00:00+00:00', 'x-cloudmap': 'routing_useast1', 'x-mode': 'ro', 'x-proxied': '10-65-108-83-useast1aprod', 'content-encoding': 'gzip', 'x-extlb': '10-65-108-83-useast1aprod', 'cache-control': 'max-age=0, no-store, private, no-transform', 'Accept-Ranges': 'bytes', 'Date': 'Thu, 16 Feb 2023 03:29:25 GMT', 'Via': '1.1 varnish', 'X-Served-By': 'cache-iah17255-IAH', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'Vary': 'Accept-Encoding', 'transfer-encoding': 'chunked'}
#
# response body is {"businesses": [{"id": "c7_PCKjymhTEx-418TUQrw", "alias": "kp-s-kitchen-houston", "name": "KP\u2019s Kitchen", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-LJMRBUGLCRuYHBU-D3MhA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kp-s-kitchen-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 166, "categories": [{"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 29.7851283, "longitude": -95.4932661}, "transactions": [], "price": "$$", "location": {"address1": "8412 Katy Fwy", "address2": "Ste 350", "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["8412 Katy Fwy", "Ste 350", "Houston, TX 77024"]}, "phone": "+17136770921", "display_phone": "(713) 677-0921", "distance": 2139.3439656421756}, {"id": "0aH34yn_UAyx5g9aGzBjZw", "alias": "ember-and-greens-houston", "name": "Ember & Greens", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/bIEXqm_P8K9kkxnOIFlfMw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ember-and-greens-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 307, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "comfortfood", "title": "Comfort Food"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.5, "coordinates": {"latitude": 29.78227, "longitude": -95.52455}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "9403B Katy Fwy", "address2": null, "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["9403B Katy Fwy", "Houston, TX 77024"]}, "phone": "+17134653333", "display_phone": "(713) 465-3333", "distance": 2467.494343094968}, {"id": "nqnD2CxTvXnkMcmSjFpd6A", "alias": "postino-town-and-country-houston-5", "name": "Postino Town & Country", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/4i15A6UISO53Cd97qM2tLA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/postino-town-and-country-houston-5?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 203, "categories": [{"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "tapasmallplates", "title": "Tapas/Small Plates"}], "rating": 4.5, "coordinates": {"latitude": 29.778048771930823, "longitude": -95.56105504344312}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "791 Town And Country Blvd", "address2": "Ste 146", "address3": null, "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["791 Town And Country Blvd", "Ste 146", "Houston, TX 77024"]}, "phone": "+17135748337", "display_phone": "(713) 574-8337", "distance": 5537.864194382998}, {"id": "hSFXjuYnlCaW25yJ005_lg", "alias": "by-popular-demand-houston", "name": "By Popular Demand", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/aq13FkuLz7EUXBLky_7tVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/by-popular-demand-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg", "review_count": 59, "categories": [{"alias": "whiskeybars", "title": "Whiskey Bars"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.5, "coordinates": {"latitude": 29.7664124, "longitude": -95.5486411}, "transactions": ["delivery"], "location": {"address1": "12420 Memorial Dr", "address2": null, "address3": "", "city": "Houston", "zip_code": "77024", "country": "US", "state": "TX", "display_address": ["12420 Memorial Dr", "Houston, TX 77024"]}, "phone": "+12815004601", "display_phone": "(281) 500-4601", "distance": 4358.258509758105}, {"id": "RTau-YpBii_bnHbSEG9z ...

# %%
#response.json() can automatically parse json text into python dict
#or you can also use json package to parse the text
response.json()
# Out:
# {'businesses': [{'id': 'c7_PCKjymhTEx-418TUQrw',
#    'alias': 'kp-s-kitchen-houston',
#    'name': 'KP’s Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-LJMRBUGLCRuYHBU-D3MhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kp-s-kitchen-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 166,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7851283, 'longitude': -95.4932661},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8412 Katy Fwy',
#     'address2': 'Ste 350',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['8412 Katy Fwy', 'Ste 350', 'Houston, TX 77024']},
#    'phone': '+17136770921',
#    'display_phone': '(713) 677-0921',
#    'distance': 2139.3439656421756},
#   {'id': '0aH34yn_UAyx5g9aGzBjZw',
#    'alias': 'ember-and-greens-houston',
#    'name': 'Ember & Greens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bIEXqm_P8K9kkxnOIFlfMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ember-and-greens-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 307,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.78227, 'longitude': -95.52455},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9403B Katy Fwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9403B Katy Fwy', 'Houston, TX 77024']},
#    'phone': '+17134653333',
#    'display_phone': '(713) 465-3333',
#    'distance': 2467.494343094968},
#   {'id': 'nqnD2CxTvXnkMcmSjFpd6A',
#    'alias': 'postino-town-and-country-houston-5',
#    'name': 'Postino Town & Country',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4i15A6UISO53Cd97qM2tLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/postino-town-and-country-houston-5?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 203,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.778048771930823,
#     'longitude': -95.56105504344312},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '791 Town And Country Blvd',
#     'address2': 'Ste 146',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['791 Town And Country Blvd',
#      'Ste 146',
#      'Houston, TX 77024']},
#    'phone': '+17135748337',
#    'display_phone': '(713) 574-8337',
#    'distance': 5537.864194382998},
#   {'id': 'hSFXjuYnlCaW25yJ005_lg',
#    'alias': 'by-popular-demand-houston',
#    'name': 'By Popular Demand',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aq13FkuLz7EUXBLky_7tVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-popular-demand-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 59,
#    'categories': [{'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7664124, 'longitude': -95.5486411},
#    'transactions': ['delivery'],
#    'location': {'address1': '12420 Memorial Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['12420 Memorial Dr', 'Houston, TX 77024']},
#    'phone': '+12815004601',
#    'display_phone': '(281) 500-4601',
#    'distance': 4358.258509758105},
#   {'id': 'RTau-YpBii_bnHbSEG9zSQ',
#    'alias': 'cosmo-eatery-houston',
#    'name': 'Cosmo Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uK4zKfozmR1j-EkuJjaXpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cosmo-eatery-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 41,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7369955801299,
#     'longitude': -95.53226558953676},
#    'transactions': [],
#    'location': {'address1': '9511 Westheimer Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77063',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9511 Westheimer Rd', 'Houston, TX 77063']},
#    'phone': '+18324005522',
#    'display_phone': '(832) 400-5522',
#    'distance': 4412.056174478347},
#   {'id': 'eVnDdQyQG3Vz9sTi0FtTpw',
#    'alias': 'one-shot-pocha-houston',
#    'name': 'One Shot Pocha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oxdEv1KSxtLJ6r3k-EKc5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-shot-pocha-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 41,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.796789, 'longitude': -95.525843},
#    'transactions': [],
#    'location': {'address1': '9501 Long Point Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77055',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9501 Long Point Rd', 'Houston, TX 77055']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3757.821072370398},
#   {'id': 'd_BLF5bq4-HBxkJ14ps7YQ',
#    'alias': 'the-general-public-houston',
#    'name': 'The General Public',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LTceXaMZfHY96F7lvp3Ibw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-general-public-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 714,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.77893869999999,
#     'longitude': -95.56183449999999},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '797 Sorella Ct',
#     'address2': 'Ste 118',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['797 Sorella Ct', 'Ste 118', 'Houston, TX 77024']},
#    'phone': '+18326904450',
#    'display_phone': '(832) 690-4450',
#    'distance': 5631.00446409367},
#   {'id': 'XT6s20ssoSh714XGHXgZ3w',
#    'alias': 'daily-gather-no-title',
#    'name': 'Daily Gather',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yhck-xAXjxMeSdfw27b9tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daily-gather-no-title?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 214,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.780459359856238,
#     'longitude': -95.56127804354273},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '800 Sorella Ct',
#     'address2': 'Ste 940',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['800 Sorella Ct', 'Ste 940', 'Houston, TX 77024']},
#    'phone': '+17134290451',
#    'display_phone': '(713) 429-0451',
#    'distance': 5615.503379480747},
#   {'id': '_o26ywhvAPI6OzBBLB6dzw',
#    'alias': 'state-fare-kitchen-and-bar-houston',
#    'name': 'State Fare Kitchen & Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WpD2Pka9he7_grF_5BnIjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/state-fare-kitchen-and-bar-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 1315,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.78362, 'longitude': -95.545838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '947 Gessner Rd',
#     'address2': 'Ste B190',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['947 Gessner Rd', 'Ste B190', 'Houston, TX 77024']},
#    'phone': '+18328310950',
#    'display_phone': '(832) 831-0950',
#    'distance': 4304.425053335279},
#   {'id': 'fjKqxzHK6z3G2V03Fnoz7g',
#    'alias': 'cowboy-surfer-houston',
#    'name': 'Cowboy Surfer',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jrGDSU27WRp9wj2QnwRhVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cowboy-surfer-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 21,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.77854, 'longitude': -95.54841},
#    'transactions': [],
#    'location': {'address1': '827 Frostwood Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['827 Frostwood Dr', 'Houston, TX 77024']},
#    'phone': '+18325380851',
#    'display_phone': '(832) 538-0851',
#    'distance': 4359.788683882085},
#   {'id': 'KbFA3To__JA7Ksj_ND31SA',
#    'alias': 'moxies-houston',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YPiaNefH9K7rTluo1s05_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 1055,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.742842539713106,
#     'longitude': -95.46139082456634},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5000 Westheimer Rd',
#     'address2': 'Ste 250',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5000 Westheimer Rd', 'Ste 250', 'Houston, TX 77056']},
#    'phone': '+13465716164',
#    'display_phone': '(346) 571-6164',
#    'distance': 5071.607968332681},
#   {'id': 'rT9n0Bj1ko9PHljZ7bITFQ',
#    'alias': 'izakaya-wa-houston',
#    'name': 'Izakaya Wa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/18aDEP3DEQvxseuE375VKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-wa-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 932,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.76747, 'longitude': -95.55882},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '12665 Memorial Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['12665 Memorial Dr', 'Houston, TX 77024']},
#    'phone': '+17134610155',
#    'display_phone': '(713) 461-0155',
#    'distance': 5226.188414324701},
#   {'id': '-29-Wp5Rr4JNf4EaN0OmcQ',
#    'alias': 'hawaiian-bros-island-grill-houston',
#    'name': 'Hawaiian Bros Island Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/URhdYKzxee8gGgjEb5A1tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawaiian-bros-island-grill-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 155,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.738104391346685, 'longitude': -95.500416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6522 Westheimer Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77057',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['6522 Westheimer Rd', 'Houston, TX 77057']},
#    'phone': '+12813053007',
#    'display_phone': '(281) 305-3007',
#    'distance': 3421.74036744419},
#   {'id': 'Eaani_7M6xAsasMnG4t5HQ',
#    'alias': 'joey-uptown-houston-2',
#    'name': 'JOEY Uptown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x2Qvy9oF56iB3DPMo8V8Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joey-uptown-houston-2?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 682,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.740252, 'longitude': -95.462682},
#    'transactions': ['delivery'],
#    'location': {'address1': '5045 Westheimer Rd',
#     'address2': 'Ste X01',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5045 Westheimer Rd', 'Ste X01', 'Houston, TX 77056']},
#    'phone': '+13466465639',
#    'display_phone': '(346) 646-5639',
#    'distance': 5135.603534004698},
#   {'id': '237MSviehmCzD_wwKg4-zA',
#    'alias': 'bosscat-kitchen-and-libations-houston',
#    'name': 'Bosscat Kitchen & Libations',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUsonAxau5HCqy3QWJVRRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 2518,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7418, 'longitude': -95.450518},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4310 Westheimer Rd',
#     'address2': 'Ste 150',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77027',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4310 Westheimer Rd', 'Ste 150', 'Houston, TX 77027']},
#    'phone': '+12815011187',
#    'display_phone': '(281) 501-1187',
#    'distance': 6013.7689518057905},
#   {'id': 'ksuEApOrjGow3BnlCerKJA',
#    'alias': 'little-hen-houston-houston',
#    'name': 'Little Hen - Houston',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pMLbrBBGSRWpWOk1l0bqLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-hen-houston-houston?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 47,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74269, 'longitude': -95.45309},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4444 Westheimer Ct',
#     'address2': 'Ste H110',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77027',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4444 Westheimer Ct',
#      'Ste H110',
#      'Houston, TX 77027']},
#    'phone': '+13468338374',
#    'display_phone': '(346) 833-8374',
#    'distance': 5678.046398788982},
#   {'id': 'l84prBJ1i95o4dyRCx-l8g',
#    'alias': 'mias-table-houston-3',
#    'name': "Mia's Table",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nzBRa5oF5u8z_r4rj1HWtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mias-table-houston-3?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 116,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.78751087218349, 'longitude': -95.5447537},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1035 Gessner Rd',
#     'address2': 'Bldg-B',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77055',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1035 Gessner Rd', 'Bldg-B', 'Houston, TX 77055']},
#    'phone': '+12818576939',
#    'display_phone': '(281) 857-6939',
#    'distance': 4397.170910029125},
#   {'id': 'encsjTTta4eRVoOUygpgmQ',
#    'alias': 'jonathans-the-rub-campbell-place-houston-2',
#    'name': "Jonathan's The Rub Campbell Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SiM3BE7BRCOHowhG6_Gnyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jonathans-the-rub-campbell-place-houston-2?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 498,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.78538423443685,
#     'longitude': -95.51301746387728},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9090 Katy Fwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9090 Katy Fwy', 'Houston, TX 77024']},
#    'phone': '+17134658200',
#    'display_phone': '(713) 465-8200',
#    'distance': 2026.1606475623664},
#   {'id': 'Qvco68LBoVnvBHcR5aMFig',
#    'alias': 'patagonia-grill-and-cafe-houston-3',
#    'name': 'Patagonia Grill & Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PecdpqTFswYBjjsUVfnuVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patagonia-grill-and-cafe-houston-3?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 284,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7852326852403,
#     'longitude': -95.4924828791099},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '8408 Katy Fwy',
#     'address2': 'Ste 220',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['8408 Katy Fwy', 'Ste 220', 'Houston, TX 77024']},
#    'phone': '+17134688408',
#    'display_phone': '(713) 468-8408',
#    'distance': 2189.0944521378597},
#   {'id': '8DLekUEGzobbBjtcs0Jtag',
#    'alias': 'treebeards-houston-7',
#    'name': 'Treebeards',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sB2QfTqRR8NkzaiDJpeqLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/treebeards-houston-7?adjust_creative=wNk7g0hjrWgyyibkXNNSBg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wNk7g0hjrWgyyibkXNNSBg',
#    'review_count': 87,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 29.781908935314053,
#     'longitude': -95.53066130403292},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9655 Katy Fwy',
#     'address2': 'Ste 3120',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77024',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9655 Katy Fwy', 'Ste 3120', 'Houston, TX 77024']},
#    'phone': '+17132282622',
#    'display_phone': '(713) 228-2622',
#    'distance': 2906.474897442345}],
#  'total': 4300,
#  'region': {'center': {'longitude': -95.50483703613281,
#    'latitude': 29.768509805418184}}}

# %%
type(response.json())
# Out:
# dict

# %%
#let's take a look at what information you can get
print(response.json().keys())
#And you can easily load it into a dataframe
import pandas as pd
businesses = response.json()['businesses']
df = pd.DataFrame(businesses)
df.to_csv("Sample_data.csv")
df.head()
# Out:
# dict_keys(['businesses', 'total', 'region'])
#                        id                               alias  \
# 0  c7_PCKjymhTEx-418TUQrw                kp-s-kitchen-houston
# 1  0aH34yn_UAyx5g9aGzBjZw            ember-and-greens-houston
# 2  nqnD2CxTvXnkMcmSjFpd6A  postino-town-and-country-houston-5
# 3  hSFXjuYnlCaW25yJ005_lg           by-popular-demand-houston
# 4  RTau-YpBii_bnHbSEG9zSQ                cosmo-eatery-houston
#
#                      name                                          image_url  \
# 0            KP’s Kitchen  https://s3-media1.fl.yelpcdn.com/bphoto/-LJMRB...
# 1          Ember & Greens  https://s3-media2.fl.yelpcdn.com/bphoto/bIEXqm...
# 2  Postino Town & Country  https://s3-media2.fl.yelpcdn.com/bphoto/4i15A6...
# 3       By Popular Demand  https://s3-media1.fl.yelpcdn.com/bphoto/aq13Fk...
# 4            Cosmo Eatery  https://s3-media1.fl.yelpcdn.com/bphoto/uK4zKf...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/kp-s-kitchen-houston?...           166
# 1      False  https://www.yelp.com/biz/ember-and-greens-hous...           307
# 2      False  https://www.yelp.com/biz/postino-town-and-coun...           203
# 3      False  https://www.yelp.com/biz/by-popular-demand-hou...            59
# 4      False  https://www.yelp.com/biz/cosmo-eatery-houston?...            41
#
#                                           categories  rating  \
# 0  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 1  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.5
# 3  [{'alias': 'whiskeybars', 'title': 'Whiskey Ba...     4.5
# 4  [{'alias': 'tradamerican', 'title': 'American ...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 29.7851283, 'longitude': -95.4932...                  []
# 1     {'latitude': 29.78227, 'longitude': -95.52455}  [pickup, delivery]
# 2  {'latitude': 29.778048771930823, 'longitude': ...  [pickup, delivery]
# 3  {'latitude': 29.7664124, 'longitude': -95.5486...          [delivery]
# 4  {'latitude': 29.7369955801299, 'longitude': -9...                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '8412 Katy Fwy', 'address2': 'Ste...  +17136770921
# 1    $$  {'address1': '9403B Katy Fwy', 'address2': Non...  +17134653333
# 2    $$  {'address1': '791 Town And Country Blvd', 'add...  +17135748337
# 3   NaN  {'address1': '12420 Memorial Dr', 'address2': ...  +12815004601
# 4   NaN  {'address1': '9511 Westheimer Rd', 'address2':...  +18324005522
#
#     display_phone     distance
# 0  (713) 677-0921  2139.343966
# 1  (713) 465-3333  2467.494343
# 2  (713) 574-8337  5537.864194
# 3  (281) 500-4601  4358.258510
# 4  (832) 400-5522  4412.056174

# %% [markdown]
# ## Sometimes you need to send data to server, let's take a look at json
#
# JSON stands for JavaScript Object Notation, it's a string representing serielized object/data, contains only data and can easily parse between all kinds of popular data format, e.g. dict, dataframe, csv file, and can be used across all languages.
#
# You will encounter JSON objects and JSON Arrays. e.g.
# {
# "name":"John",
# "age":30,
# "cars":[ "Ford", "BMW", "Fiat" ]
# }
#
# Conversion table between JSON and Python types:
#
# | JSON | Python |
# | --- | --- |
# | object | dict |
# | array | list |
# | string | str |
# | number(int/real) | int/float |
# | true/false | True/False |

# %%
import json

cars = {
    "name":"John",
    "age":"30",
    "cars":["Ford","BMW","Fiat"]
}

print('type of cars is ' + str(type(cars)))

cars_json = json.dumps(cars)
print('type of cars_json is ' + str(type(cars_json)))

cars_from_json = json.loads(cars_json)
print('type of cars_from_json is ' + str(type(cars_from_json)))
# Out:
# type of cars is <class 'dict'>
# type of cars_json is <class 'str'>
# type of cars_from_json is <class 'dict'>

# %%
# you can easily load json string into dataframe also

df_car = pd.read_json(cars_json, orient='columns')
df_car.head()
# Out:
#    name  age  cars
# 0  John   30  Ford
# 1  John   30   BMW
# 2  John   30  Fiat

# %%
## Homework: use github api to create a new repo for yourself
